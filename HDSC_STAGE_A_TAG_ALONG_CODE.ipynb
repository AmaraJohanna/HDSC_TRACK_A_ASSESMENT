# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the dataset
food = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')
food.head() #returns the first 5 observations of the dataset
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food.shape #returns the number of observations and features of the dataset
# Out:
# (60943, 12)

# %% [markdown]
# #### There ae 60943 rows and 12 columns

# %%
food.info() #returns the generalinfo of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
food.isnull().sum() #checks the number of missing values in each feature
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# All the year columns contain missing values

# %%
food.duplicated().sum() #checks for any duplicated rows
# Out:
# 0

# %% [markdown]
# ##### There are no duplicated rows in the dataset

# %% [markdown]
# #### QUIZ SECTION. (11-20)

# %% [markdown]
# Question 11
# Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# What is the total sum of Animal Fat produced in 2014 and 2017 respectively?
#
# Hint:
#
# Perform a groupby sum aggregation on ‘Item’

# %%
food.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food.Item.unique() # returns all the unique elements of the Item column
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
food.groupby('Item').sum().loc['Animal fats']
# Out:
# Area Code         85279.00
# Item Code       1882494.00
# Element Code    2567303.00
# Y2014            209460.54
# Y2015            200675.72
# Y2016            183314.22
# Y2017            269617.53
# Y2018            269648.27
# Name: Animal fats, dtype: float64

# %% [markdown]
# Question 12
# What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?

# %%
food['Y2015'].mean()
# Out:
# 135.23596649549236

# %%
food['Y2015'].std()
# Out:
# 1603.4039839423301

# %% [markdown]
# Question 13
# What is the total number and percentage of missing data in 2016 to 2 decimal places?

# %%
food['Y2016'].isnull().sum()
# Out:
# 1535

# %%
((food['Y2016'].isnull().sum())/len(food))*100
# Out:
# 2.5187470259094566

# %% [markdown]
# Question 14
# Which year had the highest correlation with ‘Element Code’?

# %%
food.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# Question 15
# What year has the highest sum of Import Quantity?
#
# Hint- Perform a groupby operation on ‘Element’ and use the resulting Dataframe to answer the question

# %%
food.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# Question 16
# What is the total number of the sum of Production in 2014?
#
# Hint- Perform a groupby operation on ‘Element’ and use the resulting Dataframe to answer the question

# %%
food.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# Question 17
# Which of these elements had the highest sum in 2018?
#
# Hint-  Select columns ‘Y2018’ and ‘Element’, Perform a groupby operation on ‘Element’ on the selected dataframe and answer the  question.

# %%
sub_food = food[['Y2018','Element']]
sub_food.head()
# Out:
#       Y2018                                 Element
# 0  42228.00           Total Population - Both sexes
# 1      0.00                Domestic supply quantity
# 2   3322.00           Food supply (kcal/capita/day)
# 3     91.83  Protein supply quantity (g/capita/day)
# 4     77.28      Fat supply quantity (g/capita/day)

# %%
sub_food.groupby('Element').sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# Question 18 Which of these elements had the 3rd lowest sum in 2018?
#
# Hint-  Select columns ‘Y2018’ and ‘Element’, Perform a groupby operation on ‘Element’ on the selected dataframe and answer the  question.

# %%
sub_food.groupby('Element').sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# Question 19 What is the total Import Quantity in Algeria in 2018?

# %%
sub_food1 = food[['Y2018','Element','Area']]
sub_food1.head()
# Out:
#       Y2018                                 Element     Area
# 0  42228.00           Total Population - Both sexes  Algeria
# 1      0.00                Domestic supply quantity  Algeria
# 2   3322.00           Food supply (kcal/capita/day)  Algeria
# 3     91.83  Protein supply quantity (g/capita/day)  Algeria
# 4     77.28      Fat supply quantity (g/capita/day)  Algeria

# %%
sub_food1.groupby(['Element','Area']).sum().loc['Import Quantity']
# Out:
#                                 Y2018
# Area
# Algeria                      36238.29
# Angola                        7769.67
# Benin                         7008.24
# Botswana                      1908.42
# Burkina Faso                  2605.64
# Cabo Verde                     499.66
# Cameroon                      4188.88
# Central African Republic        75.02
# Chad                           491.95
# Comoros                          2.92
# Congo                         1785.27
# Côte d'Ivoire                 9271.21
# Djibouti                      3784.92
# Egypt                        53954.20
# Eswatini                       936.53
# Ethiopia                      5655.24
# Ethiopia PDR                     0.00
# Gabon                         1079.75
# Gambia                        1212.10
# Ghana                         9914.68
# Guinea                        4707.95
# Guinea-Bissau                  497.72
# Kenya                        11188.96
# ...

# %% [markdown]
# Question 20
# What is the total number of unique countries in the dataset?

# %%
food.Area.nunique()
# Out:
# 49
